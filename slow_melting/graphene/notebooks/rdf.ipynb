# %%
from rdfpy import rdf
import numpy as np
import matplotlib.pyplot as plt

data = np.loadtxt("positions_5000_K.txt")[:,1:3]
g_r, radii = rdf(data, dr=0.1)

# %%
plt.plot(radii, g_r, color="red")
plt.xlim(0,10)
# Out:
# (0.0, 10.0)
