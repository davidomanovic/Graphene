# %%
import numpy as np
import matplotlib.pyplot as plt

data = np.loadtxt('thermo.txt')
step   = data[:,0]
temp   = data[:,1]
epair  = data[:,2]
emol   = data[:,3]
etot   = data[:,4]
press  = data[:,5]


plt.plot(temp, etot, label='Total Energy', linewidth=1)
plt.xlabel('Temp (K)')
plt.ylabel('Energy (eV)')
plt.legend()
plt.show()
